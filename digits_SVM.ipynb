# %%
import pandas as pd
from sklearn.datasets import load_digits

digits = load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8], shape=(1797,))

# %%
X = digits.data
y = digits.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf', C=1000)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=1000)

# %%
model.predict(X_test)
# Out:
# array([6, 2, 8, 4, 3, 1, 9, 9, 4, 6, 8, 7, 2, 3, 8, 6, 5, 3, 6, 6, 8, 6,
#        1, 2, 4, 9, 9, 3, 1, 7, 4, 2, 1, 4, 1, 4, 9, 9, 7, 0, 7, 4, 5, 0,
#        1, 7, 9, 2, 6, 8, 8, 4, 6, 4, 4, 4, 0, 3, 8, 9, 6, 3, 6, 6, 9, 7,
#        7, 7, 3, 9, 6, 1, 1, 6, 5, 6, 9, 3, 5, 0, 8, 6, 4, 6, 3, 4, 6, 5,
#        8, 4, 8, 6, 3, 3, 4, 4, 8, 3, 5, 5, 2, 2, 9, 0, 0, 4, 3, 1, 1, 2,
#        9, 9, 6, 3, 7, 2, 4, 7, 8, 9, 9, 3, 7, 8, 1, 7, 7, 6, 0, 5, 6, 4,
#        2, 0, 6, 0, 5, 9, 0, 3, 9, 0, 8, 0, 5, 3, 9, 5, 1, 6, 7, 0, 8, 4,
#        9, 0, 0, 0, 4, 0, 8, 2, 0, 5, 2, 4, 6, 1, 4, 2, 2, 0, 1, 8, 1, 3,
#        5, 5, 6, 9, 1, 2, 1, 8, 5, 1, 6, 2, 9, 7, 1, 9, 5, 3, 1, 2, 0, 0,
#        2, 7, 7, 5, 7, 4, 5, 2, 7, 2, 5, 7, 6, 4, 0, 8, 2, 2, 8, 8, 2, 0,
#        4, 5, 2, 3, 3, 7, 6, 2, 3, 7, 2, 5, 1, 3, 3, 8, 5, 2, 0, 8, 2, 7,
#        2, 9, 2, 1, 8, 2, 8, 7, 7, 3, 5, 0, 2, 1, 4, 7, 0, 2, 1, 8, 4, 0,
#        5, 1, 9, 8, 1, 9, 5, 3, 8, 3, 0, 2, 8, 9, 8, 6, 8, 3, 4, 3, 0, 3,
#        4, 4, 1, 1, 7, 3, 6, 5, 6, 2, 3, 2, 1, 2, 8, 9, 0, 4, 9, 7, 3, 6,
#        1, 7, 1, 2, 0, 0, 8, 6, 5, 6, 6, 3, 7, 1, 2, 4, 5, 2, 9, 7, 6, 9,
#        8, 1, 2, 5, 5, 1, 2, 5, 6, 6, 5, 8, 9, 1, 6, 0, 6, 7, 6, 1, 8, 2,
#        5, 9, 7, 7, 2, 8, 7, 2])

# %%
model.score(X_test, y_test)
# Out:
# 0.9944444444444445
